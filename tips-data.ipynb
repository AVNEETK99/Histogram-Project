# %%
import pandas as pd
from plotnine import ggplot, aes, facet_grid, labs, geom_col

# reading dataset
df = pd.read_csv("tips.csv")

(
	ggplot(df)
	+ facet_grid(facets="~sex")
	+ aes(x="day", y="total_bill")
	+ labs(
		x="day",
		y="total_bill",
	)
	+ geom_col()
)
# Out:
# <ggplot: (120266045317)>

# %%
import pandas as pd
from plotnine import ggplot, aes, facet_grid, labs, geom_col, theme_xkcd

# reading dataset
df = pd.read_csv("tips.csv")

(
    #partitions a plot into a matrix of panels
	ggplot(df)
	+ facet_grid(facets="~sex")
	+ aes(x="day", y="total_bill")
	+ labs(
		x="day",
		y="total_bill",
	)
	+ geom_col()
	+ theme_xkcd()
)
# Out:
# <ggplot: (120269339627)>

# %%
import pandas as pd
from plotnine import ggplot, aes, facet_grid, labs, geom_col, theme_xkcd

# reading dataset
df = pd.read_csv("tips.csv")

(
	ggplot(df)
	+ facet_grid(facets="~sex")
	+ aes(x="day", y="total_bill", fill="time")
	+ labs(
		x="day",
		y="total_bill",
	)
	+ geom_col()
	+ theme_xkcd()
)
# Out:
# <ggplot: (120269414358)>
